# %%
import pandas as pd

# %%
df_e=pd.read_excel('/Users/Jeff/Downloads/Elec-Prod-et-conso.xlsx')

# %%
df_e.head()
# Out:
#                                              Période  2011-01-01 00:00:00  \
# 0     Production totale nette d'électricité (en GWh)            58290.160
# 1   Production nette d'électricité primaire (en GWh)            51098.160
# 2  Production nette d'électricité nucléaire (en GWh)            43853.000
# 3  Production nette d'électricité hydraulique (en...             5973.754
# 4   Production nette d'électricité éolienne (en GWh)             1229.000
#
#    2011-02-01 00:00:00  2011-03-01 00:00:00  2011-04-01 00:00:00  \
# 0            50410.220            50779.430            40865.480
# 1            43335.220            43371.430            37765.480
# 2            38328.000            37688.000            32850.000
# 3             4068.702             4469.404             4078.931
# 4              871.000             1094.000              668.000
#
#    2011-05-01 00:00:00  2011-06-01 00:00:00  2011-07-01 00:00:00  \
# ...

# %%
df_e=df_e.T

# %%
df_e.reset_index(inplace=True)

# %%
df_e.columns=df_e.iloc[0]

# %%
df_e.head()
# Out:
# 0              Période  Production totale nette d'électricité (en GWh)  \
# 0              Période  Production totale nette d'électricité (en GWh)
# 1  2011-01-01 00:00:00                                         58290.2
# 2  2011-02-01 00:00:00                                         50410.2
# 3  2011-03-01 00:00:00                                         50779.4
# 4  2011-04-01 00:00:00                                         40865.5
#
# 0  Production nette d'électricité primaire (en GWh)  \
# 0  Production nette d'électricité primaire (en GWh)
# 1                                           51098.2
# 2                                           43335.2
# 3                                           43371.4
# 4                                           37765.5
#
# 0  Production nette d'électricité nucléaire (en GWh)  \
# 0  Production nette d'électricité nucléaire (en GWh)
# 1                                              43853
# 2                                              38328
# ...

# %%
df_e.drop(df_e.index[0], inplace=True)

# %%
df_e.to_csv('df_e_prod_conso.csv', sep='/', index=False)
